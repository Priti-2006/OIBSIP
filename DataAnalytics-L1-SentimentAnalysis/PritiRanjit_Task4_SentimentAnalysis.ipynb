# %% [markdown]
# # Sentiment Analysis
# ## Oasis Infobyte — Data Analytics Internship
# ### Name: Priti Ranjit | Track: Data Analytics | Task: L1 Task 4

# %% [markdown]
# ## Step 1: Inspect & Fix Column Structure

# %%
print("Number of columns:", df.shape[1])
print("\nSample row:")
print(df.iloc[0])
# Out:
# Number of columns: 10
#
# Sample row:
# 0              textID
# 1                text
# 2       selected_text
# 3           sentiment
# 4       Time of Tweet
# 5         Age of User
# 6             Country
# 7    Population -2020
# 8     Land Area (Km²)
# 9     Density (P/Km²)
# Name: 0, dtype: str

# %% [markdown]
# ## Step 1: Data Cleaning & Class Distribution
